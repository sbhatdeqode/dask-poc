# %%
from dask.distributed import Client

client = Client(n_workers=4)
client
# Out:
# /home/deq/Desktop/conda-dask/dask-example/env/lib/python3.10/site-packages/distributed/node.py:179: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 45385 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:37921' processes=4 threads=8, memory=15.38 GiB>

# %%
import os
os.path.getsize( os.path.join("data","large_file.csv"))
# Out:
# 16547227485

# %%
import time
import dask.dataframe as dd

start_time = time.time()
ddf = dd.read_csv(
    os.path.join("data","large_file.csv"),
)
ddf

load_time = time.time() - start_time
load_time
# Out:
# 0.03482937812805176

# %%
ddf.head()
# Out:
#       session_type                                             labels
# 0  12899779_clicks  59625 737445 731692 1340695 448688 601769 9415...
# 1  12899780_clicks  1142000 582732 736515 973453 1502122 889686 13...
# 2  12899781_clicks  199008 918667 528496 1836671 1681537 428697 14...
# 3  12899782_clicks  595994 834354 1696036 889671 1033148 829180 12...
# 4  12899783_clicks  1817895 58861 573058 1476106 408787 562398 738...

# %%
ddf.tail()
# Out:
#            session_type                                             labels
# 198488  14571577_clicks  1141710 1276792 1004292 1666114 842555 86916 1...
# 198489  14571578_clicks  977826 519105 815460 822641 1811714 735459 167...
# 198490  14571579_clicks  739876 1750859 1209992 51363 785544 1796451 18...
# 198491  14571580_clicks  202353 1314576 433425 925638 679257 985380 682...
# 198492  14571581_clicks  1100210 1684953 462056 1158237 1401429 622489 ...

# %%
start_time = time.time()
ddf['session_type'] = 'modified'
ddf['labels'] = 'modified'
processing_time = time.time() - start_time
processing_time
# Out:
# 0.010179996490478516

# %%
ddf.head()
# Out:
#   session_type    labels
# 0     modified  modified
# 1     modified  modified
# 2     modified  modified
# 3     modified  modified
# 4     modified  modified

# %%
start_time = time.time()
ddf.to_csv("./data/modified_large_file.csv", index=False, single_file=True)
saving_time = time.time() - start_time
saving_time
# Out:
# 127.51211452484131

# %%
start_time = time.time()
ddf.to_parquet(
    "./data/parquet", 
    compression="snappy",
    engine="pyarrow",
)
saving_time = time.time() - start_time
saving_time
# Out:
# 69.3883728981018

# %%
start_time = time.time()
ddf.to_csv(
    "./data/csv/export-*.csv", 
)
saving_time = time.time() - start_time
saving_time
# Out:
# 91.44409394264221
